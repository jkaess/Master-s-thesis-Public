# %% [markdown]
# # Bundestagsscraper:

# %% [markdown]
# ## Import & Setup

# %%
# !pip install bs4
# !pip install regex
# !pip install pandas
import regex as re
from bs4 import BeautifulSoup
import time
import pandas as pd
# Out:
# Requirement already satisfied: bs4 in /home/pc/Uni/MasterThesis/.venv/lib/python3.12/site-packages (0.0.2)
# Requirement already satisfied: beautifulsoup4 in /home/pc/Uni/MasterThesis/.venv/lib/python3.12/site-packages (from bs4) (4.13.4)
# Requirement already satisfied: soupsieve>1.2 in /home/pc/Uni/MasterThesis/.venv/lib/python3.12/site-packages (from beautifulsoup4->bs4) (2.7)
# Requirement already satisfied: typing-extensions>=4.0.0 in /home/pc/Uni/MasterThesis/.venv/lib/python3.12/site-packages (from beautifulsoup4->bs4) (4.14.1)
# Requirement already satisfied: regex in /home/pc/Uni/MasterThesis/.venv/lib/python3.12/site-packages (2024.11.6)
# Requirement already satisfied: pandas in /home/pc/Uni/MasterThesis/.venv/lib/python3.12/site-packages (2.3.0)
# Requirement already satisfied: numpy>=1.26.0 in /home/pc/Uni/MasterThesis/.venv/lib/python3.12/site-packages (from pandas) (2.3.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/pc/Uni/MasterThesis/.venv/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/pc/Uni/MasterThesis/.venv/lib/python3.12/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/pc/Uni/MasterThesis/.venv/lib/python3.12/site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in /home/pc/Uni/MasterThesis/.venv/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %% [markdown]
# # Search specifications & api requirements
# - AnfangArr is the first earlier point of the iterative timeframe that scrapes the protocols. A reasonable distance between AnfangArr and EndeArr is usually around 3 months max since the API only returns at max 10 sessions. Thus a longer timeframe will result in to many results
# - EndeArr is the latter point. If you want to scrape everything, start with the current month and iterate back to 1949
#
# **The current API key can be found here:** https://dip.bundestag.de/%C3%BCber-dip/hilfe/api#content

# %%
apiKey = "PLEASE INSERT YOUR API KEY HERE"

AnfangArr = [2025,1,1]

startDatum = str(AnfangArr[0]) + "-" + str(AnfangArr[1]) + "-" + str(AnfangArr[2])
startDatum = re.sub(r'(?<!\d)(\d)(?!\d)', r'0\1', startDatum)

EndeArr = [2025,10,2]
endDatum = str(EndeArr[0]) + "-" + str(EndeArr[1]) + "-" + str(EndeArr[2])
endDatum = re.sub(r'(?<!\d)(\d)(?!\d)', r'0\1', endDatum)

# %% [markdown]
# ## Download Funktion

# %% [markdown]
# ## Haupt-Schleife
# Testing if the URL is valid

# %%
KurzURL = "https://search.dip.bundestag.de/api/v1/plenarprotokoll?f.zuordnung=BT&f.datum.start="+startDatum+"&f.datum.end="+endDatum+"&format=xml&apikey="+apiKey
print(KurzURL)
# Out:
# https://search.dip.bundestag.de/api/v1/plenarprotokoll?f.zuordnung=BT&f.datum.start=2025-01-02&f.datum.end=2025-15-02&format=xml&apikey=OSOegLs.PR2lwJ1dwCeje9vTj7FPOt3hvpYKtwKkhw

# %%
def requester(AnfangArr, EndeArr):
    startDatum = str(AnfangArr[0]) + "-" + str(AnfangArr[1]) + "-" + str(AnfangArr[2])
    startDatum = re.sub(r'(?<!\d)(\d)(?!\d)', r'0\1', startDatum)

    endDatum = str(EndeArr[0]) + "-" + str(EndeArr[1]) + "-" + str(EndeArr[2])
    endDatum = re.sub(r'(?<!\d)(\d)(?!\d)', r'0\1', endDatum)

    KurzURL = "https://search.dip.bundestag.de/api/v1/plenarprotokoll?f.zuordnung=BT&f.datum.start="+startDatum+"&f.datum.end="+endDatum+"&format=json&apikey="+apiKey
    print(KurzURL)
    headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
    }
    req = urllib.request.Request(KurzURL, headers=headers)
    response = urllib.request.urlopen(req)
    webTextInhalt = response.read().decode('UTF-8')

    keyword = "documents"
    before_keyword, keyword, after_keyword = webTextInhalt.partition(keyword)

        #Die BundestagsAPI erlaubt nur 10 Dokumente pro Anfrage, daher wird die Anfrage aufgeteilt in 10 Dokumente pro Anfrage. Ndocs erhebt die Nummer der Dokumente innerhalb der Suchreichweite und teilt ggf die Suchreichweite auf.
    nDocs = re.findall(r'\d+', before_keyword)
    Docs = int(nDocs[0])
        
    if Docs >= 10:
        print("Zu viele Dokumente, verringere Suchbereich")

        if((AnfangArr[0] == EndeArr[0]) and (AnfangArr[2] >= 15) and (EndeArr[2] == 1)) or ((AnfangArr[0] == EndeArr[0]) and (AnfangArr[2] >= 1) and (EndeArr[2] == 15) and (AnfangArr[1] == EndeArr[1])):
            print("Suchbereich zu klein")
            AnfangArr[2] = AnfangArr[2] +1

        elif (AnfangArr[0] == EndeArr[0]) and (AnfangArr[1] == EndeArr[1]) and (AnfangArr[2] == EndeArr[2]):
            print("Suchbereich zu klein")
            AnfangArr[0] = AnfangArr[0] -1


        elif (AnfangArr[1] >= EndeArr[1]) and (AnfangArr[1] < 12) and (AnfangArr[0] < EndeArr[0]):
            print("Monat zu klein")
            AnfangArr[1] = AnfangArr[1] + 1
         

        elif (AnfangArr[1] == 12 and EndeArr[1] != 1):
            print("Jahresende")
            AnfangArr[0] = AnfangArr[0] +1
            AnfangArr[1] = 1
           
        elif (AnfangArr[1] == 12 and EndeArr[1] == 1):
            print("Jahresende mit Jahresanfangskomplöxitäten")
            AnfangArr[2] = AnfangArr[2] + 1
           
        elif (AnfangArr[1] == (EndeArr[1]-1) and (AnfangArr[0] == EndeArr[0])) and (EndeArr[2] != 15):
            print("Mehr als 10 Einträge in einem Monat")
            AnfangArr[2] = 15

        elif (AnfangArr[1] == (EndeArr[1]-1) and (AnfangArr[0] == EndeArr[0])) and (EndeArr[2] == 15):
            print("Mehr als 10 Einträge in einem Monat")
            AnfangArr[2] = 1
            AnfangArr[1] = EndeArr[1]
        

        elif ((AnfangArr[1] == 12) and (AnfangArr[2] == 15)):
            AnfangArr[0] = AnfangArr[0] + 1
            AnfangArr[1] = 1
            AnfangArr[2] = 1


        else:
            print("Iteriere Monat")
            AnfangArr[1] = AnfangArr[1] + 1
         
        AnfangStr = str(AnfangArr[0]) + "-" + str(AnfangArr[1]) + "-" + str(AnfangArr[2]) #Die API erlaubt nur Datumsanfragen im Format YYYY-MM-DD daher wird das Datum in ein String umgewandelt und eine 0 vor einstelligte Tage oder Monate gesetzt. 
        return AnfangArr

    else:
        print("N < 10. Schreibe in Datei")
        TextURL = "https://search.dip.bundestag.de/api/v1/plenarprotokoll-text?f.zuordnung=BT&f.datum.start="+startDatum+"&f.datum.end="+endDatum+"&format=json&apikey="+apiKey
        print(TextURL)
        response = urllib.request.urlopen(TextURL)
        TextInhalt = response.read().decode('UTF-8')
                
        fileName = "./TextDaten"+startDatum +"-"+ endDatum + ".txt" 
        file = open(fileName, "w")
        a = file.write(TextInhalt)
        file.close() #Datei abspeichern
        EndeArr[:] = [0, 0, 0]  
        
        print("Datei geschrieben")

        EndeArr[0] = AnfangArr[0]   #Neue Suchparameter definieren
        EndeArr[1] = AnfangArr[1]
        EndeArr[2] = AnfangArr[2]
        endDatum = str(EndeArr[0]) + "-" + str(EndeArr[1]) + "-" + str(EndeArr[2])
        endDatum = re.sub(r'(?<!\d)(\d)(?!\d)', r'0\1', endDatum)
        
        AnfangArr[0] = AnfangArr[0] -1
        AnfangArr[2] = 1
        return AnfangArr, EndeArr

# %% [markdown]
# ## V2

# %%
startDatum = str(AnfangArr[0]) + "-" + str(AnfangArr[1]) + "-" + str(AnfangArr[2])
startDatum = re.sub(r'(?<!\d)(\d)(?!\d)', r'0\1', startDatum)

endDatum = str(EndeArr[0]) + "-" + str(EndeArr[1]) + "-" + str(EndeArr[2])
endDatum = re.sub(r'(?<!\d)(\d)(?!\d)', r'0\1', endDatum)

KurzURL = "https://search.dip.bundestag.de/api/v1/plenarprotokoll?f.zuordnung=BT&f.datum.start="+startDatum+"&f.datum.end="+endDatum+"&format=json&apikey="+apiKey
print(KurzURL)
response = urllib.request.urlopen(KurzURL)
webTextInhalt = response.read().decode('UTF-8')

keyword = "documents"
before_keyword, keyword, after_keyword = webTextInhalt.partition(keyword)

    #Die BundestagsAPI erlaubt nur 10 Dokumente pro Anfrage, daher wird die Anfrage aufgeteilt in 10 Dokumente pro Anfrage. Ndocs erhebt die Nummer der Dokumente innerhalb der Suchreichweite und teilt ggf die Suchreichweite auf.
nDocs = re.findall(r'\d+', before_keyword)
Docs = int(nDocs[0])
    
if Docs > 10:
    print("Zu viele Dokumente, verringere Suchbereich")

    if (AnfangArr[0] == EndeArr[0]) and (AnfangArr[1] == EndeArr[1]) and (AnfangArr[2] == EndeArr[2]):
        print("Suchbereich zu klein")
        AnfangArr[0] = AnfangArr[0] -1

    elif (AnfangArr[1] >= EndeArr[1]) and (AnfangArr[1] < 12) and (AnfangArr[0] < EndeArr[0]):
        print("Monat zu klein")
        AnfangArr[1] = AnfangArr[1] + 1

    elif (AnfangArr[1] == 12):
        print("Jahresende")
        AnfangArr[0] = AnfangArr[0] +1
        AnfangArr[1] = 1

    elif (AnfangArr[1] == (EndeArr[1]-1) and (AnfangArr[0] == EndeArr[0])):
        print("Mehr als 10 Einträge in einem Monat")
        AnfangArr[2] = 15

    elif ((AnfangArr[1] == 12) and (AnfangArr[2] == 15)):
        AnfangArr[0] = AnfangArr[0] + 1
        AnfangArr[1] = 1
        AnfangArr[2] = 1

    else:
        print("Iteriere Monat")
        AnfangArr[1] = AnfangArr[1] + 1


    AnfangStr = str(AnfangArr[0]) + "-" + str(AnfangArr[1]) + "-" + str(AnfangArr[2]) #Die API erlaubt nur Datumsanfragen im Format YYYY-MM-DD daher wird das Datum in ein String umgewandelt und eine 0 vor einstelligte Tage oder Monate gesetzt.  
        
                

else:
    print("N < 10. Schreibe in Datei")
    TextURL = "https://search.dip.bundestag.de/api/v1/plenarprotokoll-text?f.zuordnung=BT&f.datum.start="+startDatum+"&f.datum.end="+endDatum+"&format=json&apikey="+apiKey
    print(TextURL)
    response = urllib.request.urlopen(TextURL)
    TextInhalt = response.read().decode('UTF-8')
            
    fileName = "./TextDaten"+startDatum +"-"+ endDatum + ".txt" 
    file = open(fileName, "w", encoding='utf-8')  
    a = file.write(TextInhalt)
    file.close() #Datei abspeichern
    EndeArr = [0,0,0]
    print("Datei geschrieben")

    EndeArr[0] = AnfangArr[0]   #Neue Suchparameter definieren
    EndeArr[1] = AnfangArr[1]
    EndeArr[2] = AnfangArr[2]
    endDatum = str(EndeArr[0]) + "-" + str(EndeArr[1]) + "-" + str(EndeArr[2])
    endDatum = re.sub(r'(?<!\d)(\d)(?!\d)', r'0\1', endDatum)
    
    AnfangArr[0] = AnfangArr[0] -1

# %% [markdown]
# # Applying the scraper:

# %%
while(AnfangArr[0] >= 1948 ):
    try:
        requester(AnfangArr, EndeArr)
        time.sleep(5)
    except:
        print("Fehler")
        time.sleep(600)
# Out:
# https://search.dip.bundestag.de/api/v1/plenarprotokoll?f.zuordnung=BT&f.datum.start=2025-01-01&f.datum.end=2025-10-02&format=json&apikey=OSOegLs.PR2lwJ1dwCeje9vTj7FPOt3hvpYKtwKkhw
# Zu viele Dokumente, verringere Suchbereich
# Iteriere Monat
# https://search.dip.bundestag.de/api/v1/plenarprotokoll?f.zuordnung=BT&f.datum.start=2025-02-01&f.datum.end=2025-10-02&format=json&apikey=OSOegLs.PR2lwJ1dwCeje9vTj7FPOt3hvpYKtwKkhw
# Zu viele Dokumente, verringere Suchbereich
# Iteriere Monat
# https://search.dip.bundestag.de/api/v1/plenarprotokoll?f.zuordnung=BT&f.datum.start=2025-03-01&f.datum.end=2025-10-02&format=json&apikey=OSOegLs.PR2lwJ1dwCeje9vTj7FPOt3hvpYKtwKkhw
# Zu viele Dokumente, verringere Suchbereich
# Iteriere Monat
# https://search.dip.bundestag.de/api/v1/plenarprotokoll?f.zuordnung=BT&f.datum.start=2025-04-01&f.datum.end=2025-10-02&format=json&apikey=OSOegLs.PR2lwJ1dwCeje9vTj7FPOt3hvpYKtwKkhw
# Zu viele Dokumente, verringere Suchbereich
# Iteriere Monat
# https://search.dip.bundestag.de/api/v1/plenarprotokoll?f.zuordnung=BT&f.datum.start=2025-05-01&f.datum.end=2025-10-02&format=json&apikey=OSOegLs.PR2lwJ1dwCeje9vTj7FPOt3hvpYKtwKkhw
# Zu viele Dokumente, verringere Suchbereich
# Iteriere Monat
# https://search.dip.bundestag.de/api/v1/plenarprotokoll?f.zuordnung=BT&f.datum.start=2025-06-01&f.datum.end=2025-10-02&format=json&apikey=OSOegLs.PR2lwJ1dwCeje9vTj7FPOt3hvpYKtwKkhw
# Zu viele Dokumente, verringere Suchbereich
# Iteriere Monat
# https://search.dip.bundestag.de/api/v1/plenarprotokoll?f.zuordnung=BT&f.datum.start=2025-07-01&f.datum.end=2025-10-02&format=json&apikey=OSOegLs.PR2lwJ1dwCeje9vTj7FPOt3hvpYKtwKkhw
# N < 10. Schreibe in Datei
# https://search.dip.bundestag.de/api/v1/plenarprotokoll-text?f.zuordnung=BT&f.datum.start=2025-07-01&f.datum.end=2025-10-02&format=json&apikey=OSOegLs.PR2lwJ1dwCeje9vTj7FPOt3hvpYKtwKkhw
# Datei geschrieben
# Fehler
# Cannot execute code, session has been disposed. Please try restarting the Kernel.
# Cannot execute code, session has been disposed. Please try restarting the Kernel.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
